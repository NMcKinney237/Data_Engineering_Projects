# %% [markdown]
# # Imports and Data Preprocessing

# %%
#Import Libraries
import pandas as pd
from ydata_profiling import ProfileReport
import pandera as pa
from pandera import Check, Column, DataFrameSchema

# %%
#Read In Files
df_opportunity = pd.read_excel('/Users/nathanmckinney/Desktop/Github/Data_Engineering_Projects/notebooks/Archive/data/caterpillar_analysis.xlsx', sheet_name='PTOS_source', engine='openpyxl')
df_equipment_cust = pd.read_excel('/Users/nathanmckinney/Desktop/Github/Data_Engineering_Projects/notebooks/Archive/data/caterpillar_analysis.xlsx', sheet_name='Equipment units', engine='openpyxl')
df_sales_channel = pd.read_excel('/Users/nathanmckinney/Desktop/Github/Data_Engineering_Projects/notebooks/Archive/data/caterpillar_analysis.xlsx', sheet_name='Sales channel', engine='openpyxl')

# %%
#Check
df_opportunity.head(3)
# Out:
#                       Salesman Customer ID  Segmentation           City  \
# 0  ABDULLAH AVNIABDIOGLU - 691     C531599  Do It Myself      01 ANKARA
# 1        AHMET SUHAKOCAK - 223     4013245  Do It Myself  43 DIYARBAKIR
# 2        AHMET SUHAKOCAK - 223     C528031  Do It Myself       03 ADANA
#
#    Undercarriage Opportunity  Undercarriage Sales  Engine Opportunity  \
# 0                          0                    0                 485
# 1                          0                    0                  14
# 2                        698                    0                 627
#
#    Engine Sales  GET  Opportunity  GET Sales  ...  \
# 0             0               145          0  ...
# 1             0                 0          0  ...
# 2             0               518          0  ...
#
#    Filters & Fluids Opportunity  Filters & Fluids Sales  \
# 0                           357                       0
# 1                           180                       0
# ...

# %%
#Check
df_equipment_cust.head(3)
# Out:
#                             Customer Name  Equipment units
# 0     EFUZ GELIZLIH IHLEZI GIDE - C531599                1
# 1   EZ-DEN YUL INHEEG GEEH.GUZ. - 4013245                2
# 2  HEGIPUGLU INH GEEH HEN VE GI - C528031                1

# %%
#Check
df_sales_channel.head(3)
# Out:
#                                  customer name  Work Order  \
# 0     EFUZ GELIZLIH IHLEZI GIDE - C531599  - G           0
# 1  EHDEGLEZ NIHEL LED.HEN.VE GI - C527998  - G           0
# 2  DIZELCILEZ UGULUGIVGIC.VE HE - 310650   - G           0
#
#    Over the Counter Sales
# 0                       0
# 1                       0
# 2                       0

# %%
# Make required changes to

# %%
profile = ProfileReport(df, minimal = True)

profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-10-29 22:20:44.890144&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
schema = pa.DataFrameSchema({
    # built-in python types
    "int_column": pa.Column(int),
    "float_column": pa.Column(float),
    "str_column": pa.Column(str),

    # pandas dtype string aliases
    "int_column2": pa.Column("int64"),
    "float_column2": pa.Column("float64"),
    # pandas > 1.0.0 support native "string" type
    "str_column2": pa.Column("str")
})

# %%
schema(df1)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# /Users/nathanmckinney/Desktop/Github/Data_Engineering_Projects/notebooks/catepillar interview.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/Users/nathanmckinney/Desktop/Github/Data_Engineering_Projects/notebooks/catepillar%20interview.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> schema(df1)
#
# File ~/.pyenv/versions/3.9.7/envs/dbt/lib/python3.9/site-packages/pandera/api/pandas/container.py:439, in DataFrameSchema.__call__(self, dataframe, head, tail, sample, random_state, lazy, inplace)
#     411 def __call__(
#     412     self,
#     413     dataframe: pd.DataFrame,
#    (...)
#     419     inplace: bool = False,
#     420 ):
#     421     """Alias for :func:`DataFrameSchema.validate` method.
#     422
#     423     :param pd.DataFrame dataframe: the dataframe to be validated.
#    (...)
# ...
